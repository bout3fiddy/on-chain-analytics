# %%
import os
import json
from web3 import Web3, HTTPProvider

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

from utils.subgraph_utils.convex_community import get_curve_fees

# %%
ALCHEMY_API_KEY = os.environ['ALCHEMY_API_KEY']
web3 = Web3(HTTPProvider(f"https://eth-mainnet.alchemyapi.io/v2/{ALCHEMY_API_KEY}"))

# %%
pool_addr = "0x5a6A4D54456819380173272A5E8E9B9904BdF41B"
lp_token_addr = "0x5a6A4D54456819380173272A5E8E9B9904BdF41B"
threecrv_addr = "0x6c3F90f043a72FA612cbac8115EE7e52BDe6E490"
mim_addr = "0x99D8a9C45b2ecA8864373A26D1459e3Dff1e17F3"

# %%
admin_claim_addrs = "0xA464e6DCda8AC41e03616F95f4BC98a13b8922Dc"
admin = "0xeCb456EA5365865EbAb8a2661B0c503410e9B347"

# %%
pool_addr.lower()
# Out:
# '0x5a6a4d54456819380173272a5e8e9b9904bdf41b'

# %% [markdown]
# Need individual coin addrs:

# %%
with open("./3crv.json", 'r') as f:
    abi = json.load(f)
threecrv = web3.eth.contract(address=threecrv_addr, abi=abi)

with open("./mim.json", 'r') as f:
    abi = json.load(f)
mim = web3.eth.contract(address=mim_addr, abi=abi)

# %%
subgraph_tripool_fees = get_curve_fees(pool_token_addr=lp_token_addr)
blocks = list([int(i) for i in subgraph_tripool_fees.block.values])
subgraph_block_ranges = list(zip(blocks, blocks[1:]))
subgraph_tripool_fees.index = subgraph_tripool_fees.block

# %%
fees_for_range = []
for (block_start, block_end) in subgraph_block_ranges:

    print(f"Chain checkoooor-ing blocks: {block_start}:{block_end}")

    mim_transfer_filter = mim.events.Transfer.createFilter(
        fromBlock=block_start,
        toBlock=block_end
    )
    all_transfers = mim_transfer_filter.get_all_entries()
    mim_fees = 0
    for transfer in all_transfers:

        to_address = transfer['args']['_to']
        from_address = transfer['args']['_from']
        value = transfer['args']['_value']
        block = transfer['blockNumber']

        if (
                from_address == pool_addr and
                to_address in [admin_claim_addrs, admin]
        ):
            mim_fees += value*1e-18

    threecrv_transfer_filter = threecrv.events.Transfer.createFilter(
        fromBlock=block_start,
        toBlock=block_end
    )
    all_transfers = threecrv_transfer_filter.get_all_entries()
    threecrv_fees = 0
    for transfer in all_transfers:

        to_address = transfer['args']['_to']
        from_address = transfer['args']['_from']
        value = transfer['args']['_value']
        block = transfer['blockNumber']

        if (
                from_address == pool_addr and
                to_address in [admin_claim_addrs, admin]
        ):
            threecrv_fees += value*1e-18

    dict_fees = {
        'block_start': block_start,
        'block_end': block_end,
        'mim_fees': mim_fees,
        'threecrv_fees': threecrv_fees
    }
    fees_for_range.append(dict_fees)

df_fees = pd.DataFrame(fees_for_range)
df_fees
# Out:
# Chain checkoooor-ing blocks: 13007147:13052446
# Chain checkoooor-ing blocks: 13052446:13097719
# Chain checkoooor-ing blocks: 13097719:13142950
# Chain checkoooor-ing blocks: 13142950:13189474
# Chain checkoooor-ing blocks: 13189474:13233504
# Chain checkoooor-ing blocks: 13233504:13279324
# Chain checkoooor-ing blocks: 13279324:13324114
# Chain checkoooor-ing blocks: 13324114:13368595
# Chain checkoooor-ing blocks: 13368595:13413314
# Chain checkoooor-ing blocks: 13413314:13458926
# Chain checkoooor-ing blocks: 13458926:13509655
# Chain checkoooor-ing blocks: 13509655:13549403
# Chain checkoooor-ing blocks: 13549403:13592432
#     block_start  block_end  mim_fees  threecrv_fees
# 0      13007147   13052446         0    4724.549683
# 1      13052446   13097719         0    8638.651864
# 2      13097719   13142950         0   20415.714743
# 3      13142950   13189474         0   26713.612449
# 4      13189474   13233504         0   41242.086418
# 5      13233504   13279324         0   56961.519587
# 6      13279324   13324114         0   62661.197829
# 7      13324114   13368595         0   84228.663777
# 8      13368595   13413314         0  107905.246067
# 9      13413314   13458926         0  105771.202716
# 10     13458926   13509655         0  118414.500275
# 11     13509655   13549403         0  114639.560130
# 12     13549403   13592432         0  107604.074109

# %%
df_fees['total_fees'] = df_fees.mim_fees + df_fees.threecrv_fees
df_fees.index = df_fees.block_end
df_fees
# Out:
#            block_start  block_end  mim_fees  threecrv_fees     total_fees
# block_end
# 13052446      13007147   13052446         0    4724.549683    4724.549683
# 13097719      13052446   13097719         0    8638.651864    8638.651864
# 13142950      13097719   13142950         0   20415.714743   20415.714743
# 13189474      13142950   13189474         0   26713.612449   26713.612449
# 13233504      13189474   13233504         0   41242.086418   41242.086418
# 13279324      13233504   13279324         0   56961.519587   56961.519587
# 13324114      13279324   13324114         0   62661.197829   62661.197829
# 13368595      13324114   13368595         0   84228.663777   84228.663777
# 13413314      13368595   13413314         0  107905.246067  107905.246067
# 13458926      13413314   13458926         0  105771.202716  105771.202716
# 13509655      13458926   13509655         0  118414.500275  118414.500275
# 13549403      13509655   13549403         0  114639.560130  114639.560130
# 13592432      13549403   13592432         0  107604.074109  107604.074109

# %%
fig, ax = plt.subplots(1,1, figsize=(20, 8))

(df_fees['total_fees']*2).plot(
    ax=ax,
    color='red',
    kind='bar',
    label='Admin fee claims x 2',
    width=0.2,
    position=1,
)
subgraph_tripool_fees['fees'].plot(
    ax=ax,
    color='blue',
    kind='bar',
    label='Subgraph revenue',
    width=0.2,
    position=2,
)

ax.set_ylabel("Pool Revenue [$]", fontsize=25)
ax.set_xlabel("Block Number", fontsize=25)
ax.tick_params(axis='both', which='major', labelsize=25, colors='black')
ax.yaxis.get_major_formatter().set_scientific(False)
ax.yaxis.get_major_formatter().set_useOffset(False)
ax.legend(fontsize=25);

# %% [markdown]
# hmm something strange. let's check admin balances:

# %%
with open("./withdraw_admin_fees_txes.json", 'r') as f:
    withdraw_admin_fee_events = json.load(f)['data']['claims']
withdraw_admin_fee_events
# Out:
# [{'block': '13590175',
#   'receiver': '0xecb456ea5365865ebab8a2661b0c503410e9b347',
#   'timestamp': '1636570051',
#   'transaction': '0x1fb617bacef040e74bc73a7054a86276e9bb88c10a7e5108b1be0b874dbd48f6'},
#  {'block': '13539610',
#   'receiver': '0xecb456ea5365865ebab8a2661b0c503410e9b347',
#   'timestamp': '1635884402',
#   'transaction': '0x3a09cfa73d297822ef16f1856e7e83e6faed21769e11cc7136dde24a9e64b0cc'},
#  {'block': '13497659',
#   'receiver': '0xecb456ea5365865ebab8a2661b0c503410e9b347',
#   'timestamp': '1635313880',
#   'transaction': '0x667db8dc4d89347a4c5e6c4dfd1899399f702de4daf34a6e7571342b5918a8f4'},
#  {'block': '13450705',
#   'receiver': '0xecb456ea5365865ebab8a2661b0c503410e9b347',
#   'timestamp': '1634680333',
#   'transaction': '0x4d9dbe9e800bb2b4f01a749f08d87c7c61ba85d44fad5da1b76385c6459d41cd'},
#  {'block': '13409100',
#   'receiver': '0xecb456ea5365865ebab8a2661b0c503410e9b347',
#   'timestamp': '1634115428',
#   'transaction': '0x9597c2c26a4bed9a6ce727c1a92dd30a77af50a4bcce359a94abf6a374e816cf'},
#  {'block': '13363637',
#   'receiver': '0xecb456ea5365865ebab8a2661b0c503410e9b347',
#   'timestamp': '1633498949',
#   'transaction': '0x0bddd42d460b9580ce21cb01feb947129f34c09c4c3540d1f44e79e59a4ff76a'},
#  {'block': '13363613',
#   'receiver': '0xecb456ea5365865ebab8a2661b0c503410e9b347',
#   'timestamp': '1633498617',
#   'transaction': '0x6e297f7c95ace9783f45d73d985f9bffb44742df67df36e574d0d6c652d78393'},
#  {'block': '13322180',
#   'receiver': '0xecb456ea5365865ebab8a2661b0c503410e9b347',
#   'timestamp': '1632938814',
#   'transaction': '0x68fb8c13fbd488edb202ce28a4650009173a943e4211c9070dc96ff8dea972bb'},
#  {'block': '13273795',
#   'receiver': '0xecb456ea5365865ebab8a2661b0c503410e9b347',
#   'timestamp': '1632289641',
#   'transaction': '0x72095a7b426d6fcf7123e326ba164b6868d1ebf6bf4b7bd15b0e7a02abf84c9f'},
#  {'block': '13226455',
#   'receiver': '0xecb456ea5365865ebab8a2661b0c503410e9b347',
#   'timestamp': '1631657414',
#   'transaction': '0x604930e621edafa98daf59c33f808b1c6ce0e09a4ef85b27677b47166589b0d2'},
#  {'block': '13184132',
#   'receiver': '0xecb456ea5365865ebab8a2661b0c503410e9b347',
#   'timestamp': '1631091114',
#   'transaction': '0xadf20bf46fdd85de0ce9fc63a9075d9fbac0d1889b51c74d9969c5e36a21896e'},
#  {'block': '13184006',
#   'receiver': '0xecb456ea5365865ebab8a2661b0c503410e9b347',
#   'timestamp': '1631089636',
#   'transaction': '0x8b58d3964ee99c7e1bf4c69311dd53ac890e4a1805e2f801c61850eab89dd242'},
#  {'block': '13183983',
#   'receiver': '0xecb456ea5365865ebab8a2661b0c503410e9b347',
#   'timestamp': '1631089386',
#   'transaction': '0xda2106ee4e495be78f397326f56554f71e8becbbb5fe5e2226e84cdc0d37e589'},
#  {'block': '13183969',
#   'receiver': '0xecb456ea5365865ebab8a2661b0c503410e9b347',
#   'timestamp': '1631089151',
#   'transaction': '0xd7400c8810b2ce59d261a5bfcfd237243e943ab3989808b4bfbd17953d690164'},
#  {'block': '13141087',
#   'receiver': '0xecb456ea5365865ebab8a2661b0c503410e9b347',
#   'timestamp': '1630517135',
#   'transaction': '0x8d3ee6ba564378d593b4b89f599c248d6833675431cdf998c1186d35c03345e1'},
#  {'block': '13090562',
#   'receiver': '0xecb456ea5365865ebab8a2661b0c503410e9b347',
#   'timestamp': '1629841058',
#   'transaction': '0xe06869dd0edbcfee0bf75c0c55da2729e6c46a92b8e05611a1698c6a5b37276f'},
#  {'block': '13050314',
#   'receiver': '0xecb456ea5365865ebab8a2661b0c503410e9b347',
#   'timestamp': '1629304535',
#   'transaction': '0xd2653709f8e381c51922f6d66d52d56946f1cc6e0fc87eb8276d2f61a9c2612f'},
#  {'block': '13001876',
#   'receiver': '0xecb456ea5365865ebab8a2661b0c503410e9b347',
#   'timestamp': '1628657794',
#   'transaction': '0x21e3c2463732a293d3fce426cbd62616a941cea85a6a03b7e3cadda4efd268bd'},
#  {'block': '12954345',
#   'receiver': '0xecb456ea5365865ebab8a2661b0c503410e9b347',
#   'timestamp': '1628020981',
#   'transaction': '0x42ee0b32203f50adfec85099ea93d1edee69c10a976a9bd6668f5f573d63ac1c'},
#  {'block': '12916203',
#   'receiver': '0xecb456ea5365865ebab8a2661b0c503410e9b347',
#   'timestamp': '1627499926',
#   'transaction': '0x06e334698a81cf0205366a667b98ecb79047aa0d7d2cecca9310c80de0f0c667'},
#  {'block': '12871303',
#   'receiver': '0x00000000',
#   'timestamp': '1626890997',
#   'transaction': '0x6389728750f5b4109c76f6766758ee9859540a6afedaa8984064f69e8e1c5f30'},
#  {'block': '12823273',
#   'receiver': '0x00000000',
#   'timestamp': '1626240523',
#   'transaction': '0x5d53b6177a3be405cdbf054c4f85e0697a0a5c5f8ffee7a25ebd4a7773c6a08c'},
#  {'block': '12776068',
#   'receiver': '0x00000000',
#   'timestamp': '1625603337',
#   'transaction': '0xc39828c4a511bd80959032649bc9b7ba5ccee02c1be3de7c4a94f0d7bb46251e'},
#  {'block': '12730677',
#   'receiver': '0x00000000',
#   'timestamp': '1624993064',
#   'transaction': '0x16c85efec8c6a407d108b6c7861aedee8e02443eaad4ffcd850a6a3e7449e9d9'},
#  {'block': '12691178',
#   'receiver': '0x00000000',
#   'timestamp': '1624462258',
#   'transaction': '0x745394173e9e8c902d010ded15000aa388c46fff484b1975e9fc10cadd438fea'},
#  {'block': '12645061',
#   'receiver': '0x00000000',
#   'timestamp': '1623840639',
#   'transaction': '0x169fd867ed3d2c26550e45c985f4f0c82c6f70f5ce4c7f8731c3b56070a525ea'},
#  {'block': '12598467',
#   'receiver': '0x00000000',
#   'timestamp': '1623216556',
#   'transaction': '0xd30a19162788be8e882acfc973e030139a296a789088c2f16b5aa12820bf8a36'}]

# %%
pool_addr
# Out:
# '0x5a6A4D54456819380173272A5E8E9B9904BdF41B'

# %%
with open("./mim-3pool.json", 'r') as f:
    abi = json.load(f)
mim_3pool = web3.eth.contract(address=pool_addr, abi=abi)

# %%
admin_balances_before_claim = []
for claim in withdraw_admin_fee_events:

    block = int(claim['block']) - 1
    admin_balances = (
        mim_3pool.functions.admin_balances(0).call(block_identifier=block)*1e-18,
        mim_3pool.functions.admin_balances(1).call(block_identifier=block)*1e-18,
    )
    admin_balances_before_claim.append(
        {
            "block": block,
            "to_claim": sum(admin_balances)
        }
    )
df_admin_balances = pd.DataFrame(admin_balances_before_claim)
df_admin_balances.index = df_admin_balances.block

# %%
aggregated_claims = []
blocks = []
for (block_start, block_end) in subgraph_block_ranges:

    aggregated_claims.append(
        df_admin_balances.to_claim.where(
            (block_start < df_admin_balances.block) & (df_admin_balances.block < block_end)
        ).sum()
    )
    blocks.append(block_end)

aggregated_claims
# Out:
# [4775.209730871071,
#  8702.593366681176,
#  20551.670923008016,
#  26895.26835542624,
#  41502.08327220226,
#  57355.12654268666,
#  63117.76370554969,
#  84868.23578872306,
#  108795.9736685843,
#  106382.41891014391,
#  119211.10353512618,
#  115467.93325616248,
#  108544.58733970037]

# %%
df_aggregated_claims = pd.DataFrame(data=aggregated_claims, index=blocks, columns=['to_claim'])
df_aggregated_claims
# Out:
#                to_claim
# 13052446    4775.209731
# 13097719    8702.593367
# 13142950   20551.670923
# 13189474   26895.268355
# 13233504   41502.083272
# 13279324   57355.126543
# 13324114   63117.763706
# 13368595   84868.235789
# 13413314  108795.973669
# 13458926  106382.418910
# 13509655  119211.103535
# 13549403  115467.933256
# 13592432  108544.587340

# %%
fig, ax = plt.subplots(1,1, figsize=(20, 8))

(df_fees['total_fees']*2).plot(
    ax=ax,
    color='red',
    kind='bar',
    label='Admin fee claims x 2',
    width=0.2,
    position=1,
)
subgraph_tripool_fees['fees'].plot(
    ax=ax,
    color='blue',
    kind='bar',
    label='Subgraph revenue',
    width=0.2,
    position=2,
)
(df_aggregated_claims['to_claim']*2).plot(
    ax=ax,
    color='green',
    kind='bar',
    label='Admin Balance To Claim x 2',
    width=0.2,
    position=3,
)

ax.set_ylabel("Pool Revenue [$]", fontsize=25)
ax.set_xlabel("Block Number", fontsize=25)
ax.tick_params(axis='both', which='major', labelsize=25, colors='black')
ax.yaxis.get_major_formatter().set_scientific(False)
ax.yaxis.get_major_formatter().set_useOffset(False)
ax.legend(fontsize=25);

# %% [markdown]
# Hmm Recreating the vprice formula:
#
# fees = ((virtual_price_week_1 - virtual_price_week_0) / virtual_price_week_0)) * tvl_week_0

# %%
fees_for_range = []
for (block_start, block_end) in subgraph_block_ranges:

    vp_0 = mim_3pool.functions.get_virtual_price().call(block_identifier=block_start)*1e-18
    vp_1 = mim_3pool.functions.get_virtual_price().call(block_identifier=block_end)*1e-18
    vp_growth = (vp_1 - vp_0) / vp_0

    total_mim_0 = mim_3pool.functions.balances(0).call(block_identifier=block_start)
    total_3crv_0 = mim_3pool.functions.balances(1).call(block_identifier=block_start)
    tvl_0 = (total_mim_0 + total_3crv_0)*1e-18

    total_mim_1 = mim_3pool.functions.balances(0).call(block_identifier=block_end)
    total_3crv_1 = mim_3pool.functions.balances(1).call(block_identifier=block_end)
    tvl_1 = (total_mim_1 + total_3crv_1)*1e-18

    tvl_change = tvl_1 / tvl_0

    vprice_fees_method_0 = vp_growth * tvl_0/tvl_change * 2
    admin_fee_claims = df_fees.loc[block_end, 'total_fees'] * 2

    dict_fees = {
        'block_start': block_start,
        'block_end': block_end,
        'vprice_fees_method_0': vprice_fees_method_0,
        'admin_fee_claims': admin_fee_claims,
        'difference': vprice_fees_method_0 - admin_fee_claims,
        'tvl_0': tvl_0,
        'tvl_1': tvl_1,
        'tvl_change': tvl_1 - tvl_0,
        'tvl_change_ratio': tvl_change,
        'vprice_growth': vp_growth,
        'tvl_0/tvl_change': tvl_0/tvl_change
    }
    fees_for_range.append(dict_fees)

df_vprice_fees = pd.DataFrame(fees_for_range)
df_vprice_fees
# Out:
#     block_start  block_end  vprice_fees_method_0  admin_fee_claims  \
# 0      13007147   13052446          12421.306781       9449.099365
# 1      13052446   13097719          27954.967858      17277.303728
# 2      13097719   13142950          20369.912595      40831.429486
# 3      13142950   13189474          37919.461158      53427.224898
# 4      13189474   13233504          75819.272857      82484.172837
# 5      13233504   13279324         101960.635168     113923.039175
# 6      13279324   13324114         150422.565897     125322.395657
# 7      13324114   13368595         158649.312199     168457.327554
# 8      13368595   13413314         203022.272376     215810.492134
# 9      13413314   13458926         415282.883713     211542.405433
# 10     13458926   13509655         372841.319893     236829.000549
# 11     13509655   13549403         300388.909986     229279.120260
# 12     13549403   13592432         406665.677089     215208.148219
#
#        difference         tvl_0         tvl_1    tvl_change  tvl_change_ratio  \
# 0     2972.207416  9.110991e+07  1.137305e+08  2.262064e+07          1.248279
# 1    10677.664130  1.137305e+08  1.167727e+08  3.042126e+06          1.026749
# 2   -20461.516891  1.167727e+08  2.018495e+08  8.507688e+07          1.728568
# 3   -15507.763740  2.018495e+08  3.566925e+08  1.548430e+08          1.767121
# 4    -6664.899980  3.566925e+08  5.101185e+08  1.534259e+08          1.430135
# 5   -11962.404007  5.101185e+08  6.852032e+08  1.750848e+08          1.343224
# 6    25100.170239  6.852032e+08  9.322064e+08  2.470031e+08          1.360482
# 7    -9808.015355  9.322064e+08  1.409260e+09  4.770540e+08          1.511747
# 8   -12788.219758  1.409260e+09  1.954317e+09  5.450562e+08          1.386768
# 9   203740.478280  1.954317e+09  2.122909e+09  1.685921e+08          1.086267
# 10  136012.319343  2.122909e+09  2.362274e+09  2.393658e+08          1.112754
# 11   71109.789725  2.362274e+09  2.544026e+09  1.817516e+08          1.076939
# 12  191457.528871  2.544026e+09  2.543323e+09 -7.028201e+05          0.999724
#
#     vprice_growth  tvl_0/tvl_change
# 0        0.000085      7.298844e+07
# 1        0.000126      1.107677e+08
# 2        0.000151      6.755456e+07
# 3        0.000166      1.142251e+08
# 4        0.000152      2.494118e+08
# 5        0.000134      3.797718e+08
# 6        0.000149      5.036476e+08
# 7        0.000129      6.166417e+08
# 8        0.000100      1.016220e+09
# 9        0.000115      1.799113e+09
# 10       0.000098      1.907797e+09
# 11       0.000068      2.193508e+09
# 12       0.000080      2.544729e+09

# %%
fig, ax = plt.subplots(1,1, figsize=(20, 8))

subgraph_tripool_fees['fees'].plot(
    ax=ax,
    color='blue',
    kind='bar',
    label='Subgraph revenue',
    width=0.2,
    position=1,
)
(df_vprice_fees['vprice_fees_method_0']*2).plot(
    ax=ax,
    color='green',
    kind='bar',
    label='VPrice Method 0',
    width=0.2,
    position=2,
)
(df_fees['total_fees']*2).plot(
    ax=ax,
    color='red',
    kind='bar',
    label='Admin fee claims x 2',
    width=0.2,
    position=3,
)

ax.set_ylabel("Pool Revenue [$]", fontsize=25)
ax.set_xlabel("Block Number", fontsize=25)
ax.tick_params(axis='both', which='major', labelsize=25, colors='black')
ax.yaxis.get_major_formatter().set_scientific(False)
ax.yaxis.get_major_formatter().set_useOffset(False)
ax.legend(fontsize=25);

# %% [markdown]
# hmm reducing ranges:

# %%
finer_block_steps = list(range(subgraph_block_ranges[0][0], subgraph_block_ranges[-1][-1], 1000))
finer_block_range = list(zip(finer_block_steps, finer_block_steps[1:]))
finer_block_range
# Out:
# [(13007147, 13008147),
#  (13008147, 13009147),
#  (13009147, 13010147),
#  (13010147, 13011147),
#  (13011147, 13012147),
#  (13012147, 13013147),
#  (13013147, 13014147),
#  (13014147, 13015147),
#  (13015147, 13016147),
#  (13016147, 13017147),
#  (13017147, 13018147),
#  (13018147, 13019147),
#  (13019147, 13020147),
#  (13020147, 13021147),
#  (13021147, 13022147),
#  (13022147, 13023147),
#  (13023147, 13024147),
#  (13024147, 13025147),
#  (13025147, 13026147),
#  (13026147, 13027147),
#  (13027147, 13028147),
#  (13028147, 13029147),
#  (13029147, 13030147),
#  (13030147, 13031147),
#  (13031147, 13032147),
#  (13032147, 13033147),
#  (13033147, 13034147),
#  (13034147, 13035147),
#  (13035147, 13036147),
#  (13036147, 13037147),
#  (13037147, 13038147),
#  (13038147, 13039147),
#  (13039147, 13040147),
#  (13040147, 13041147),
#  (13041147, 13042147),
#  (13042147, 13043147),
#  (13043147, 13044147),
#  (13044147, 13045147),
#  (13045147, 13046147),
#  (13046147, 13047147),
#  (13047147, 13048147),
#  (13048147, 13049147),
#  (13049147, 13050147),
#  (13050147, 13051147),
#  (13051147, 13052147),
#  (13052147, 13053147),
#  (13053147, 13054147),
#  (13054147, 13055147),
#  (13055147, 13056147),
#  (13056147, 13057147),
#  (13057147, 13058147),
#  (13058147, 13059147),
#  (13059147, 13060147),
#  (13060147, 13061147),
#  (13061147, 13062147),
#  (13062147, 13063147),
#  (13063147, 13064147),
#  (13064147, 13065147),
#  (13065147, 13066147),
#  (13066147, 13067147),
#  (13067147, 13068147),
#  (13068147, 13069147),
#  (13069147, 13070147),
#  (13070147, 13071147),
#  (13071147, 13072147),
#  (13072147, 13073147),
#  (13073147, 13074147),
#  (13074147, 13075147),
#  (13075147, 13076147),
#  (13076147, 13077147),
#  (13077147, 13078147),
#  (13078147, 13079147),
#  (13079147, 13080147),
#  (13080147, 13081147),
#  (13081147, 13082147),
#  (13082147, 13083147),
#  (13083147, 13084147),
#  (13084147, 13085147),
#  (13085147, 13086147),
#  (13086147, 13087147),
#  (13087147, 13088147),
#  (13088147, 13089147),
#  (13089147, 13090147),
#  (13090147, 13091147),
#  (13091147, 13092147),
#  (13092147, 13093147),
#  (13093147, 13094147),
#  (13094147, 13095147),
#  (13095147, 13096147),
#  (13096147, 13097147),
#  (13097147, 13098147),
#  (13098147, 13099147),
#  (13099147, 13100147),
#  (13100147, 13101147),
#  (13101147, 13102147),
#  (13102147, 13103147),
#  (13103147, 13104147),
#  (13104147, 13105147),
#  (13105147, 13106147),
#  (13106147, 13107147),
#  (13107147, 13108147),
#  (13108147, 13109147),
#  (13109147, 13110147),
#  (13110147, 13111147),
#  (13111147, 13112147),
#  (13112147, 13113147),
#  (13113147, 13114147),
#  (13114147, 13115147),
#  (13115147, 13116147),
#  (13116147, 13117147),
#  (13117147, 13118147),
#  (13118147, 13119147),
#  (13119147, 13120147),
#  (13120147, 13121147),
#  (13121147, 13122147),
#  (13122147, 13123147),
#  (13123147, 13124147),
#  (13124147, 13125147),
#  (13125147, 13126147),
#  (13126147, 13127147),
#  (13127147, 13128147),
#  (13128147, 13129147),
#  (13129147, 13130147),
#  (13130147, 13131147),
#  (13131147, 13132147),
#  (13132147, 13133147),
#  (13133147, 13134147),
#  (13134147, 13135147),
#  (13135147, 13136147),
#  (13136147, 13137147),
#  (13137147, 13138147),
#  (13138147, 13139147),
#  (13139147, 13140147),
#  (13140147, 13141147),
#  (13141147, 13142147),
#  (13142147, 13143147),
#  (13143147, 13144147),
#  (13144147, 13145147),
#  (13145147, 13146147),
#  (13146147, 13147147),
#  (13147147, 13148147),
#  (13148147, 13149147),
#  (13149147, 13150147),
#  (13150147, 13151147),
#  (13151147, 13152147),
#  (13152147, 13153147),
#  (13153147, 13154147),
#  (13154147, 13155147),
#  (13155147, 13156147),
#  (13156147, 13157147),
#  (13157147, 13158147),
#  (13158147, 13159147),
#  (13159147, 13160147),
#  (13160147, 13161147),
#  (13161147, 13162147),
#  (13162147, 13163147),
#  (13163147, 13164147),
#  (13164147, 13165147),
#  (13165147, 13166147),
#  (13166147, 13167147),
#  (13167147, 13168147),
#  (13168147, 13169147),
#  (13169147, 13170147),
#  (13170147, 13171147),
#  (13171147, 13172147),
#  (13172147, 13173147),
#  (13173147, 13174147),
#  (13174147, 13175147),
#  (13175147, 13176147),
#  (13176147, 13177147),
#  (13177147, 13178147),
#  (13178147, 13179147),
#  (13179147, 13180147),
#  (13180147, 13181147),
#  (13181147, 13182147),
#  (13182147, 13183147),
#  (13183147, 13184147),
#  (13184147, 13185147),
#  (13185147, 13186147),
#  (13186147, 13187147),
#  (13187147, 13188147),
#  (13188147, 13189147),
#  (13189147, 13190147),
#  (13190147, 13191147),
#  (13191147, 13192147),
#  (13192147, 13193147),
#  (13193147, 13194147),
#  (13194147, 13195147),
#  (13195147, 13196147),
#  (13196147, 13197147),
#  (13197147, 13198147),
#  (13198147, 13199147),
#  (13199147, 13200147),
#  (13200147, 13201147),
#  (13201147, 13202147),
#  (13202147, 13203147),
#  (13203147, 13204147),
#  (13204147, 13205147),
#  (13205147, 13206147),
#  (13206147, 13207147),
#  (13207147, 13208147),
#  (13208147, 13209147),
#  (13209147, 13210147),
#  (13210147, 13211147),
#  (13211147, 13212147),
#  (13212147, 13213147),
#  (13213147, 13214147),
#  (13214147, 13215147),
#  (13215147, 13216147),
#  (13216147, 13217147),
#  (13217147, 13218147),
#  (13218147, 13219147),
#  (13219147, 13220147),
#  (13220147, 13221147),
#  (13221147, 13222147),
#  (13222147, 13223147),
#  (13223147, 13224147),
#  (13224147, 13225147),
#  (13225147, 13226147),
#  (13226147, 13227147),
#  (13227147, 13228147),
#  (13228147, 13229147),
#  (13229147, 13230147),
#  (13230147, 13231147),
#  (13231147, 13232147),
#  (13232147, 13233147),
#  (13233147, 13234147),
#  (13234147, 13235147),
#  (13235147, 13236147),
#  (13236147, 13237147),
#  (13237147, 13238147),
#  (13238147, 13239147),
#  (13239147, 13240147),
#  (13240147, 13241147),
#  (13241147, 13242147),
#  (13242147, 13243147),
#  (13243147, 13244147),
#  (13244147, 13245147),
#  (13245147, 13246147),
#  (13246147, 13247147),
#  (13247147, 13248147),
#  (13248147, 13249147),
#  (13249147, 13250147),
#  (13250147, 13251147),
#  (13251147, 13252147),
#  (13252147, 13253147),
#  (13253147, 13254147),
#  (13254147, 13255147),
#  (13255147, 13256147),
#  (13256147, 13257147),
#  (13257147, 13258147),
#  (13258147, 13259147),
#  (13259147, 13260147),
#  (13260147, 13261147),
#  (13261147, 13262147),
#  (13262147, 13263147),
#  (13263147, 13264147),
#  (13264147, 13265147),
#  (13265147, 13266147),
#  (13266147, 13267147),
#  (13267147, 13268147),
#  (13268147, 13269147),
#  (13269147, 13270147),
#  (13270147, 13271147),
#  (13271147, 13272147),
#  (13272147, 13273147),
#  (13273147, 13274147),
#  (13274147, 13275147),
#  (13275147, 13276147),
#  (13276147, 13277147),
#  (13277147, 13278147),
#  (13278147, 13279147),
#  (13279147, 13280147),
#  (13280147, 13281147),
#  (13281147, 13282147),
#  (13282147, 13283147),
#  (13283147, 13284147),
#  (13284147, 13285147),
#  (13285147, 13286147),
#  (13286147, 13287147),
#  (13287147, 13288147),
#  (13288147, 13289147),
#  (13289147, 13290147),
#  (13290147, 13291147),
#  (13291147, 13292147),
#  (13292147, 13293147),
#  (13293147, 13294147),
#  (13294147, 13295147),
#  (13295147, 13296147),
#  (13296147, 13297147),
#  (13297147, 13298147),
#  (13298147, 13299147),
#  (13299147, 13300147),
#  (13300147, 13301147),
#  (13301147, 13302147),
#  (13302147, 13303147),
#  (13303147, 13304147),
#  (13304147, 13305147),
#  (13305147, 13306147),
#  (13306147, 13307147),
#  (13307147, 13308147),
#  (13308147, 13309147),
#  (13309147, 13310147),
#  (13310147, 13311147),
#  (13311147, 13312147),
#  (13312147, 13313147),
#  (13313147, 13314147),
#  (13314147, 13315147),
#  (13315147, 13316147),
#  (13316147, 13317147),
#  (13317147, 13318147),
#  (13318147, 13319147),
#  (13319147, 13320147),
#  (13320147, 13321147),
#  (13321147, 13322147),
#  (13322147, 13323147),
#  (13323147, 13324147),
#  (13324147, 13325147),
#  (13325147, 13326147),
#  (13326147, 13327147),
#  (13327147, 13328147),
#  (13328147, 13329147),
#  (13329147, 13330147),
#  (13330147, 13331147),
#  (13331147, 13332147),
#  (13332147, 13333147),
#  (13333147, 13334147),
#  (13334147, 13335147),
#  (13335147, 13336147),
#  (13336147, 13337147),
#  (13337147, 13338147),
#  (13338147, 13339147),
#  (13339147, 13340147),
#  (13340147, 13341147),
#  (13341147, 13342147),
#  (13342147, 13343147),
#  (13343147, 13344147),
#  (13344147, 13345147),
#  (13345147, 13346147),
#  (13346147, 13347147),
#  (13347147, 13348147),
#  (13348147, 13349147),
#  (13349147, 13350147),
#  (13350147, 13351147),
#  (13351147, 13352147),
#  (13352147, 13353147),
#  (13353147, 13354147),
#  (13354147, 13355147),
#  (13355147, 13356147),
#  (13356147, 13357147),
#  (13357147, 13358147),
#  (13358147, 13359147),
#  (13359147, 13360147),
#  (13360147, 13361147),
#  (13361147, 13362147),
#  (13362147, 13363147),
#  (13363147, 13364147),
#  (13364147, 13365147),
#  (13365147, 13366147),
#  (13366147, 13367147),
#  (13367147, 13368147),
#  (13368147, 13369147),
#  (13369147, 13370147),
#  (13370147, 13371147),
#  (13371147, 13372147),
#  (13372147, 13373147),
#  (13373147, 13374147),
#  (13374147, 13375147),
#  (13375147, 13376147),
#  (13376147, 13377147),
#  (13377147, 13378147),
#  (13378147, 13379147),
#  (13379147, 13380147),
#  (13380147, 13381147),
#  (13381147, 13382147),
#  (13382147, 13383147),
#  (13383147, 13384147),
#  (13384147, 13385147),
#  (13385147, 13386147),
#  (13386147, 13387147),
#  (13387147, 13388147),
#  (13388147, 13389147),
#  (13389147, 13390147),
#  (13390147, 13391147),
#  (13391147, 13392147),
#  (13392147, 13393147),
#  (13393147, 13394147),
#  (13394147, 13395147),
#  (13395147, 13396147),
#  (13396147, 13397147),
#  (13397147, 13398147),
#  (13398147, 13399147),
#  (13399147, 13400147),
#  (13400147, 13401147),
#  (13401147, 13402147),
#  (13402147, 13403147),
#  (13403147, 13404147),
#  (13404147, 13405147),
#  (13405147, 13406147),
#  (13406147, 13407147),
#  (13407147, 13408147),
#  (13408147, 13409147),
#  (13409147, 13410147),
#  (13410147, 13411147),
#  (13411147, 13412147),
#  (13412147, 13413147),
#  (13413147, 13414147),
#  (13414147, 13415147),
#  (13415147, 13416147),
#  (13416147, 13417147),
#  (13417147, 13418147),
#  (13418147, 13419147),
#  (13419147, 13420147),
#  (13420147, 13421147),
#  (13421147, 13422147),
#  (13422147, 13423147),
#  (13423147, 13424147),
#  (13424147, 13425147),
#  (13425147, 13426147),
#  (13426147, 13427147),
#  (13427147, 13428147),
#  (13428147, 13429147),
#  (13429147, 13430147),
#  (13430147, 13431147),
#  (13431147, 13432147),
#  (13432147, 13433147),
#  (13433147, 13434147),
#  (13434147, 13435147),
#  (13435147, 13436147),
#  (13436147, 13437147),
#  (13437147, 13438147),
#  (13438147, 13439147),
#  (13439147, 13440147),
#  (13440147, 13441147),
#  (13441147, 13442147),
#  (13442147, 13443147),
#  (13443147, 13444147),
#  (13444147, 13445147),
#  (13445147, 13446147),
#  (13446147, 13447147),
#  (13447147, 13448147),
#  (13448147, 13449147),
#  (13449147, 13450147),
#  (13450147, 13451147),
#  (13451147, 13452147),
#  (13452147, 13453147),
#  (13453147, 13454147),
#  (13454147, 13455147),
#  (13455147, 13456147),
#  (13456147, 13457147),
#  (13457147, 13458147),
#  (13458147, 13459147),
#  (13459147, 13460147),
#  (13460147, 13461147),
#  (13461147, 13462147),
#  (13462147, 13463147),
#  (13463147, 13464147),
#  (13464147, 13465147),
#  (13465147, 13466147),
#  (13466147, 13467147),
#  (13467147, 13468147),
#  (13468147, 13469147),
#  (13469147, 13470147),
#  (13470147, 13471147),
#  (13471147, 13472147),
#  (13472147, 13473147),
#  (13473147, 13474147),
#  (13474147, 13475147),
#  (13475147, 13476147),
#  (13476147, 13477147),
#  (13477147, 13478147),
#  (13478147, 13479147),
#  (13479147, 13480147),
#  (13480147, 13481147),
#  (13481147, 13482147),
#  (13482147, 13483147),
#  (13483147, 13484147),
#  (13484147, 13485147),
#  (13485147, 13486147),
#  (13486147, 13487147),
#  (13487147, 13488147),
#  (13488147, 13489147),
#  (13489147, 13490147),
#  (13490147, 13491147),
#  (13491147, 13492147),
#  (13492147, 13493147),
#  (13493147, 13494147),
#  (13494147, 13495147),
#  (13495147, 13496147),
#  (13496147, 13497147),
#  (13497147, 13498147),
#  (13498147, 13499147),
#  (13499147, 13500147),
#  (13500147, 13501147),
#  (13501147, 13502147),
#  (13502147, 13503147),
#  (13503147, 13504147),
#  (13504147, 13505147),
#  (13505147, 13506147),
#  (13506147, 13507147),
#  (13507147, 13508147),
#  (13508147, 13509147),
#  (13509147, 13510147),
#  (13510147, 13511147),
#  (13511147, 13512147),
#  (13512147, 13513147),
#  (13513147, 13514147),
#  (13514147, 13515147),
#  (13515147, 13516147),
#  (13516147, 13517147),
#  (13517147, 13518147),
#  (13518147, 13519147),
#  (13519147, 13520147),
#  (13520147, 13521147),
#  (13521147, 13522147),
#  (13522147, 13523147),
#  (13523147, 13524147),
#  (13524147, 13525147),
#  (13525147, 13526147),
#  (13526147, 13527147),
#  (13527147, 13528147),
#  (13528147, 13529147),
#  (13529147, 13530147),
#  (13530147, 13531147),
#  (13531147, 13532147),
#  (13532147, 13533147),
#  (13533147, 13534147),
#  (13534147, 13535147),
#  (13535147, 13536147),
#  (13536147, 13537147),
#  (13537147, 13538147),
#  (13538147, 13539147),
#  (13539147, 13540147),
#  (13540147, 13541147),
#  (13541147, 13542147),
#  (13542147, 13543147),
#  (13543147, 13544147),
#  (13544147, 13545147),
#  (13545147, 13546147),
#  (13546147, 13547147),
#  (13547147, 13548147),
#  (13548147, 13549147),
#  (13549147, 13550147),
#  (13550147, 13551147),
#  (13551147, 13552147),
#  (13552147, 13553147),
#  (13553147, 13554147),
#  (13554147, 13555147),
#  (13555147, 13556147),
#  (13556147, 13557147),
#  (13557147, 13558147),
#  (13558147, 13559147),
#  (13559147, 13560147),
#  (13560147, 13561147),
#  (13561147, 13562147),
#  (13562147, 13563147),
#  (13563147, 13564147),
#  (13564147, 13565147),
#  (13565147, 13566147),
#  (13566147, 13567147),
#  (13567147, 13568147),
#  (13568147, 13569147),
#  (13569147, 13570147),
#  (13570147, 13571147),
#  (13571147, 13572147),
#  (13572147, 13573147),
#  (13573147, 13574147),
#  (13574147, 13575147),
#  (13575147, 13576147),
#  (13576147, 13577147),
#  (13577147, 13578147),
#  (13578147, 13579147),
#  (13579147, 13580147),
#  (13580147, 13581147),
#  (13581147, 13582147),
#  (13582147, 13583147),
#  (13583147, 13584147),
#  (13584147, 13585147),
#  (13585147, 13586147),
#  (13586147, 13587147),
#  (13587147, 13588147),
#  (13588147, 13589147),
#  (13589147, 13590147),
#  (13590147, 13591147),
#  (13591147, 13592147)]

# %%
fees_for_range = []
for (block_start, block_end) in finer_block_range:

    vp_0 = mim_3pool.functions.get_virtual_price().call(block_identifier=block_start)*1e-18
    vp_1 = mim_3pool.functions.get_virtual_price().call(block_identifier=block_end)*1e-18
    vp_growth = (vp_1 - vp_0) / vp_0

    total_mim_0 = mim_3pool.functions.balances(0).call(block_identifier=block_start)
    total_3crv_0 = mim_3pool.functions.balances(1).call(block_identifier=block_start)
    tvl_0 = (total_mim_0 + total_3crv_0)*1e-18

    total_mim_1 = mim_3pool.functions.balances(0).call(block_identifier=block_end)
    total_3crv_1 = mim_3pool.functions.balances(1).call(block_identifier=block_end)
    tvl_1 = (total_mim_1 + total_3crv_1)*1e-18

    vprice_fees_method_0 = vp_growth * tvl_0

    dict_fees = {
        'block_start': block_start,
        'block_end': block_end,
        'vprice_fees_method_0': vprice_fees_method_0,
    }
    fees_for_range.append(dict_fees)

df_vprice_fees = pd.DataFrame(fees_for_range)

# %%
aggregated_claims = []
blocks = []
for (block_start, block_end) in subgraph_block_ranges:

    aggregated_claims.append(
        df_vprice_fees.vprice_fees_method_0.where(
            (block_start < df_vprice_fees.block_end) & (df_vprice_fees.block_end < block_end)
        ).sum()
    )
    blocks.append(block_end)

df_aggregated_fees = pd.DataFrame(data=aggregated_claims, index=blocks, columns=['fees'])
df_aggregated_fees
# Out:
#                    fees
# 13052446    8076.194461
# 13097719   14293.766969
# 13142950   24852.704476
# 13189474   47054.009309
# 13233504   61937.660868
# 13279324   81415.924464
# 13324114  122626.336660
# 13368595  150392.673117
# 13413314  165335.420229
# 13458926  232685.834974
# 13509655  212036.559308
# 13549403  168736.549180
# 13592432  206785.350000

# %%
fig, ax = plt.subplots(1,1, figsize=(20, 8))

# subgraph_tripool_fees['fees'].plot(
#     ax=ax,
#     color='blue',
#     kind='bar',
#     label='Subgraph revenue',
#     width=0.2,
#     position=1,
# )
(df_aggregated_fees['fees']*2).plot(
    ax=ax,
    color='blue',
    kind='bar',
    label='VPrice Method 0: 1000 block intervals',
    width=0.4,
    position=1,
)
(df_fees['total_fees']*2).plot(
    ax=ax,
    color='red',
    kind='bar',
    label='Admin fee claims x 2',
    width=0.4,
    position=2,
)

ax.set_ylabel("Pool Revenue [$]", fontsize=25)
ax.set_xlabel("Block Number", fontsize=25)
ax.set_title("Pool: MIM-3CRV", fontsize=25)
ax.tick_params(axis='both', which='major', labelsize=25, colors='black')
ax.yaxis.get_major_formatter().set_scientific(False)
ax.yaxis.get_major_formatter().set_useOffset(False)
ax.legend(fontsize=25);
